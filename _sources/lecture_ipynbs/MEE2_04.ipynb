# %% [markdown]
# # 8 数値計算における誤差

# %% [markdown]
# 数値計算とはその名のとおりコンピュータを用いて計算を行うことです。その際に必ずしもコンピュータは正しい値を計算してくれるとは限りません。そもそも原理的に正しい値を計算できない場合もあります。何らかの理由により現れる実際の数値計算結果と理論値との差のことを**誤差**と呼びますが、ここでは誤差について少し考えることで数値計算の限界や注意点について学ぶこととしましょう。

# %% [markdown]
# ## 8.1 打ち切り誤差

# %% [markdown]
# 原理的に厳密に解けない方程式を解く場合に、何らかの近似を使って解くことがあります。例えば、ある関数をテーラー展開し有限項で打ち切る場合がそれにあたります。このような場合、有限項で打ち切ったことで生じる誤差は計算機の性質とは無関係に表れる誤差であり**打ち切り誤差**と呼ばれます。
# 例えば，マクローリン展開で2次で打ち止めたとき
# $f(x)\approx f(0)+\displaystyle{\frac{1}{1!}f'(0)x+\frac{1}{2!}f'(0)x^2+O(x^3)}$
#
# 当然ですが，3次以上の高次項の分だけずれるわけです．

# %% [markdown]
# ## 8.2 コンピュータ内での小数点の表し方（浮動小数点）

# %% [markdown]
# 実数（連続量）を取り扱う多くの数値計算では小数の取り扱いが重要となります。現在、コンピュータで数値計算を行う場合小数を**浮動小数点**という方法でコンピューター内で表しています。$\beta$進$t$桁の浮動小数点数$\bar{x}$は次のようにコンピューター内で表現されます。
#
# $\bar{x}=\pm(d_0+\frac{d_1}{\beta}+\frac{d_2}{\beta^{2}}+\cdots+\frac{d_{t-1}}{\beta^{t-1}})\times \beta^e \\
# =\pm(d_0.d_1d_2 \cdots d_{t-1})_\beta \times \beta^e
# $
#
# ここで$\pm$を**符号**、$e$を**指数**、$(d_0.d_1d_2 \cdots d_{t-1})_\beta$を**仮数**と言います。浮動小数点では指数部$\beta^e$と仮数部$(d_0.d_1d_2 \cdots d_{t-1})_\beta$の対で表されるため、数によって小数点の位置が動きます（$d_0 \neq 0$）。
# （例、10進3桁の場合）
#  1. $0.00123=1.23 \times 10^{-3}$
#  1. $1.23=1.23 \times 10^{0}$

# %% [markdown]
# ## 8.3 桁落ち

# %% [markdown]
# 実数を扱う場合に計算機が各変数を有限の桁数しか格納できない事から生じる誤差のことです。非常に近い2つの数の引き算を行う場合に出てくる解の精度が元の数の精度より非常に悪くなる場合です。
# （例、10進6桁の場合）
# $x=\sqrt{10001} \approx 100.005 = 1.00005 \times 10^2$、$y=\sqrt{10000} = 100 = 1.00000 \times 10^2$とする。
# $x-y=(1.0005-1.00000) \times 10^2 = (0.00005) \times 10^2 = 5 \times 10^{-3}$
# となり、有効桁数は1桁となる。これが桁落ちの典型例です。このような場合には引き算を足し算に変形するとうまくいきます。
# $\sqrt{10001}-\sqrt{10000}= \displaystyle{\frac{1}{\sqrt{10001}+\sqrt{10000}}\\
# =\frac{1}{(0.100005+0.100000)\times 10^3}\\
# =\frac{(1.00000)\times 10^0}{(2.00005)\times 10^2}=\frac{1.00000}{2.00005}\times 10^{-2}\\
# =4.99988 \times 10^{-3}}$

# %% [markdown]
# ## 8.4 丸め誤差

# %% [markdown]
# これも計算機が有限の桁数しか格納できない事から生じる誤差になります。例えば、64bitの計算機を使っている場合、符号に1bit、指数部$e$に11bit、仮数部に53bitを使って実数を表現しています。この場合、$2^{53} \approx 10^{17}$より18桁以降は切り捨てられるか四捨五入されています。この誤差のことを**丸め誤差**と呼びます。丸め誤差はとても小さい誤差ですが演算を繰り返し行う数値シミュレーションを実行する場合などでは致命的な間違いにつながることがあるので要注意です。

# %% [markdown]
# ### 問題
# $x=0.537, y=0.612, z=0.123$とする。10進3桁切り捨て（4桁目を切り捨て）の計算機を使っている場合、次の値を手で計算せよ。
# 1. $(x+y)+z$
# 1. $x+(y+z)$

# %% [markdown]
# # 9 方程式の解法

# %% [markdown]
# 簡単な方程式の解を数値的に求める方法から始めます。様々な工学モデルや自然・社会現象の数理モデルを方程式$f(x)=0$で表す場合に、その解を数値的に求めたい場合があります。もし、$f(x)$の微分$f'(x)$が求まるのならば**ニュートン法**を使うのが便利です。また、$f'(x)$が求められない場合には解をはさむように初期値を取って解を求める**二分法**が便利です。ここではニュートン法について説明します。

# %% [markdown]
# ## 9.1 ニュートン法

# %% [markdown]
# 非線形方程式を解くための基本的な手法になります。反復によって解に収束させていくアルゴリズムであることから**反復法**と呼ばれます。ニュートン法はアルゴリズムが簡単かつ収束が速いことが知られており、より改良された反復法のアルゴリズムの基礎になっています。特に多くの応用例（例えば、機械学習）として最適化問題（要するに関数の最小値を求める問題）があります。最適化問題を解く場合にもよく反復法が用いられます。
# ニュートン法の原理は次の通りです。
#
# （ニュートン法については黒板で説明）
#
# 方程式$f(x)=0$、導関数$f'(x)$とした時に精度$\epsilon > 0$、最大反復数$n_{max}$という条件の下、ニュートン法で解を求める手順（アルゴリズム）は下記のとおりです。

# %% [markdown]
# ### アルゴリズム（ニュートン法）
# 1. 初期値$x_0$（精度$\epsilon$、最大反復回数$n_{max}$）を決める。
# 1. $\displaystyle {x_{i+1}=x_{i}-\frac{f(x_i)}{f'(x_i)}}$・・・・$(a)$式
# 1. (a)　$|x_{i+1}-x_i|> \epsilon$ かつ繰り返し回数$n < n_{max}$ならば2へ戻る。
# (b)　$|x_{i+1}-x_i|< \epsilon$ならば$x_{i+1}$は解である。
# (c)　それ以外のとき、解なし。

# %% [markdown]
# ### 問題1
# $x^2-1=0$をニュートン法を用いて数値的に解きなさい。初期値は$x=7$、精度$\epsilon < 10^{-6}$とする（最大反復回数は少ない回数（10回以内）で自分で試しながら決めなさい）。絶対値については`numpy`ライブラリを読み込み絶対値関数`np.abs()`を使いなさい。

# %% [markdown]
# ### ヒント（・・・と言うより、ほぼソースコード）

# %%
#ニュートン法1（numpy配列を用いる）
import numpy as np

epsilon=10e-6 #精度の設定
n_max=10 #最大繰り返し回数の設定
x_i=np.zeros(n_max+1) #1ステップ毎のxの値
delta=np.abs(epsilon*100) # 解の精度の初期値x_(i+1)-x_(i)
x_i[0]=x_0 #初期値の設定

n=0 #カウンタ変数
while 条件の設定: #反復を行う条件の設定
    （1行目）このブロックについては自分で考える
    （2行目）このブロックについては自分で考える
    n+=1
    print("x_i[{}]={:.12}, x_i[{}]={:.16}, delta={:.12}".format(n-1, x_i[n-1], n, x_i[n], delta))
if 条件の設定: #解の精度の設定
    print("x={}".format(x_i[n]))
else:
    print("解なし")
# Out:
#   File "/tmp/ipykernel_2048/4006526977.py", line 12
#     （1行目）このブロックについては自分で考える
#                          ^
# SyntaxError: invalid character in identifier

# %%
#解答ニュートン法1（numpy配列を用いる）
import numpy as np

x_0=7 #初期値
epsilon=10e-6 #精度の設定
n_max=10 #最大繰り返し回数の設定
x_i=np.zeros(n_max+1)#xの配列の初期化
delta=np.abs(epsilon*100)#x_(n+1)-x_nの初期値
x_i[0]=x_0 #xの初期値
n=0 #カウンタ変数の初期化

while delta > epsilon and n<n_max:#反復を行う条件の設定
    x_i[n+1]=x_i[n]-(x_i[n]**2-1)/(2*x_i[n])
    delta=np.abs(x_i[n+1]-x_i[n])
    n+=1
    #print("delta={}, x_i[{}]={}".format(delta, n, x_i[n]))
    print(f"x_i[{n-1}]={x_i[n-1]:.8}, x_i[{n}]={x_i[n]:.8}, delta={delta:.8}")
if delta < 10e-6:
    print(f"x={x_i[n]}")
else:
    print("解なし")
# Out:
# x_i[0]=7.0, x_i[1]=3.5714286, delta=3.4285714
# x_i[1]=3.5714286, x_i[2]=1.9257143, delta=1.6457143
# x_i[2]=1.9257143, x_i[3]=1.2225011, delta=0.70321323
# x_i[3]=1.2225011, x_i[4]=1.0202481, delta=0.20225293
# x_i[4]=1.0202481, x_i[5]=1.0002009, delta=0.020047205
# x_i[5]=1.0002009, x_i[6]=1.0, delta=0.00020090485
# x_i[6]=1.0, x_i[7]=1.0, delta=2.018138e-08
# x=1.0000000000000002

# %% [markdown]
# 上記のプログラムを変更し，もう少しスマートなプログラムを考えてみます。

# %%
#ニュートン法2（配列を使わない）
import numpy as np

x=7.0 #初期値
epsilon=10e-6 #精度の設定
n_max=10 #最大繰り返し回数の設定
x_new=x+epsilon*100
delta=np.abs(x_new-x)

n=0
while 条件の設定: #反復を行う条件の設定
    （1行目）このブロックについては自分で考える
    （2行目）このブロックについては自分で考える
    （3行目）このブロックについては自分で考える
    （4行目）このブロックについては自分で考える
    #print("x_new={:.8}, x={:.8}, delta={:.8}".format(x_new, x, delta))

    
if delta < 10e-6:
    print(f"x={x}")
else:
    print("解なし")
# Out:
#   File "/tmp/ipykernel_2048/2177569910.py", line 12
#     （1行目）このブロックについては自分で考える
#                          ^
# SyntaxError: invalid character in identifier

# %%
#解答ニュートン法2（配列を使わない）
import numpy as np

x=7.0 #初期値
epsilon=10e-6 #精度の設定
n_max=10 #最大繰り返し回数の設定
x_new=x+epsilon*100
delta=np.abs(x_new-x)

n=0
while delta > 10e-6 and n<10:
    x_new=x-(x**2-1)/(2*x)
    delta=np.abs(x_new-x)
    n+=1
    print(f"x_new={x_new:.8}, x={x:.8}, delta={delta:.8}")
    x=x_new
    
if delta < 10e-6:
    print(f"x={x}")
else:
    print("解なし")
# Out:
# x_new=3.5714286, x=7.0, delta=3.4285714
# x_new=1.9257143, x=3.5714286, delta=1.6457143
# x_new=1.2225011, x=1.9257143, delta=0.70321323
# x_new=1.0202481, x=1.2225011, delta=0.20225293
# x_new=1.0002009, x=1.0202481, delta=0.020047205
# x_new=1.0, x=1.0002009, delta=0.00020090485
# x_new=1.0, x=1.0, delta=2.018138e-08
# x=1.0000000000000002

# %% [markdown]
# さて、このプログラムはメインプログラムにニュートン法のアルゴリズムと方程式の両方が記述されており、ニュートン法の部分と方程式部分の区別がつきにくいです。そこで、関数を用いて改良します。

# %%
# ニュートン法3（関数使用）
import numpy as np

def newton(x, epsilon=10e-4, n_max=100):
    """ニュートン法のアルゴリズム（関数使用）"""
    n=0
    x_new=x+epsilon*100
    delta=np.abs(x-x_new)
    while 条件の設定:       
        この条件は自分で考えること
    if 条件の設定:
        print("x={}".format(x1))
    else:
        print("解なし")

def f(x): # 初めの式
    return x**2-1

def df(x): # 微分した式
    return 2*x

if __name__=='__main__': # 実行するメインコード
    x=7       #初期値の設定  
    epsilon=10e-6 #精度の設定  
    n_max=10   #最大繰り返し回数の設定  
    newton(x, epsilon, n_max)

# %%
# 解答ニュートン法3（関数使用）
import numpy as np

def newton(x, epsilon=10e-4, n_max=100):
    """ニュートン法のアルゴリズム（関数使用）"""
    n=0
    x_new=x+epsilon*100
    delta=np.abs(x-x_new)
    print(delta)
    while delta > 10e-6 and n<10:       
        x_new=x-f(x)/df(x)
        delta=np.abs(x_new-x)
        n+=1
        #print("x_new={:.8}, x={:.8}, delta={:.8}".format(x_new, x, delta))
        x=x_new
    if delta < 10e-6:
        print(f"x={x_new}")
    else:
        print("解なし")

def f(x): # 初めの式
    return x**2-1

def df(x): # 微分した式
    return 2*x

if __name__=='__main__': # 実行するメインコード
    x=7       #初期値の設定  
    epsilon=10e-6 #精度の設定  
    n_max=10   #最大繰り返し回数の設定  
    newton(x, epsilon, n_max)
# Out:
# 0.001000000000000334
# x=1.0000000000000002

# %% [markdown]
# ## 15.2 2分法

# %% [markdown]
# 　もう一つ方程式の解を求める手法として**2分法**があります。2分法の原理は「中間値の定理」に基づいてます。
#
# 中間値の定理
# 関数$f(x)$は閉区間$[a, b]$で連続かつ$f(a)\neq f(b)$ならば、$f(a)$と$f(b)$の間の任意の数$k$に対して$f(c)=k$となる$c (a < c < b)$が存在する。
#
# この事から$f(a)$と$f(b)$が異符号、つまり$f(a)f(b)<0$ならば、
#
# $f(c)=0$、$a<c<b$
#
# となる$c$が必ず見つかります。これを利用して$f(x)=0$の解を見つける手法が2分法です。2分法は中間値の定理を用いているため、$f(a)f(b)<0$を満たしていないような解をもつ方程式に使用することはできません（例えば、$(x-1)^2=0$のような偶数重解）。

# %% [markdown]
# ### アルゴリズム（2分法）
# 1. （何らかの方法で）$f(x_1)f(x_2)<0$を満たす閉区間$[x_1,x_2]$を見つける。
# 1. 中間点$\displaystyle {x_3 = \frac{x_1+x_2}{2}}$
# 1. (a). $f(x_1)f(x_3)<0$なら$x_2=x_3$
# (b). $f(x_2)f(x_3)<0$なら$x_1=x_3$
# 1. (a). $|x_2-x_1|<\epsilon$ならば$x_3$が解となる
# (b). $x_2-x_1>\epsilon$なら2へ戻る

# %% [markdown]
# さて、ここで「$f(x_1)f(x_2)<0$を満たす閉区間$[x_1, x_2]$を見つける」方法について考えてみます。最も単純な方法は最初の区間をいくつかの微小区間$[x_{k-1}, x_k]$に分割して$f(x_{k-1})f(x_k)<0$を確認する方法です。

# %% [markdown]
# ### アルゴリズム（$f(x_1)f(x_2)<0$を満たす閉区間$[x_1, x_2]$を見つける）
# 1. 最初の区間$[x_{min}, x_{max}]$および微小区間の幅$h$を与える。
# 1. $\displaystyle{n=\frac{(x_{max}-x_{min})}{h}}$として分割数を定め，$x_0=x_{min}$とする。
# 1. $k=1, 2, \cdots , n$に対して、次の手順を実行する。
# (a). $x_k=x_{min}+kh$
# (b). $f(x_{k-1})f(x_k)<0$ならば、区間$[x_{k-1}, x_k]$を2分法を適用する対象区間にする。

# %%
import numpy as np

x_min = 0
x_max = 10
h = 0.001
n = int((x_max - x_min)/h)
x_a = x_min
x_b = x_max

def f(x):
    return x**2 - 2
    
for k in range(1,n):
    x_k = x_min + k*h
    x_k_n = x_min + (k-1)*h
    if f(x_k_n)*f(x_k) < 0:
        x_a = x_k_n
        x_b = x_k
        break

print(f"[x_a, x_b] = [{x_a}, {x_b}]")
# Out:
# [x_a, x_b] = [1.414, 1.415]

# %% [markdown]
# ### 問題2
# $x^2-2=0$を2分法を用いて数値的に解きなさい。精度$\epsilon < 10^{-6}$とし、初めの最大区間は$[0, 10]$とする。

# %%
# 解答
import numpy as np

X_MIN=0
X_MAX=10
EPSILON=10e-6

def func01(x):
    return x**2 - 2
    
x1=X_MIN
x2=X_MAX
x3=(X_MIN+X_MAX)/2.0
while True:
    print(f"範囲x1={x1}, x2={x2}\n解{x3}")
    if func01(x1)*func01(x3)<0:
        x2=x3
    else:
        x1=x3
    if np.abs(x2-x1)<EPSILON:
        print(f"範囲x1={x1}, x2={x2}\n解{x3}")
        break
    x3=(x1+x2)/2.0
# Out:
# 範囲x1=0, x2=10
# 解5.0
# 範囲x1=0, x2=5.0
# 解2.5
# 範囲x1=0, x2=2.5
# 解1.25
# 範囲x1=1.25, x2=2.5
# 解1.875
# 範囲x1=1.25, x2=1.875
# 解1.5625
# 範囲x1=1.25, x2=1.5625
# 解1.40625
# 範囲x1=1.40625, x2=1.5625
# 解1.484375
# 範囲x1=1.40625, x2=1.484375
# 解1.4453125
# 範囲x1=1.40625, x2=1.4453125
# 解1.42578125
# 範囲x1=1.40625, x2=1.42578125
# 解1.416015625
# 範囲x1=1.40625, x2=1.416015625
# 解1.4111328125
# 範囲x1=1.4111328125, x2=1.416015625
# 解1.41357421875
# 範囲x1=1.41357421875, x2=1.416015625
# 解1.414794921875
# 範囲x1=1.41357421875, x2=1.414794921875
# 解1.4141845703125
# 範囲x1=1.4141845703125, x2=1.414794921875
# 解1.41448974609375
# 範囲x1=1.4141845703125, x2=1.41448974609375
# 解1.414337158203125
# 範囲x1=1.4141845703125, x2=1.414337158203125
# 解1.4142608642578125
# 範囲x1=1.4141845703125, x2=1.4142608642578125
# 解1.4142227172851562
# 範囲x1=1.4141845703125, x2=1.4142227172851562
# 解1.4142036437988281
# 範囲x1=1.4142036437988281, x2=1.4142227172851562
# 解1.4142131805419922
# 範囲x1=1.4142131805419922, x2=1.4142227172851562
# 解1.4142131805419922

# %% [markdown]
# ### レポート問題
# 問題1（numpy配列バージョン、配列を使わないバージョン、関数を用いたバージョン)および問題2プログラムを作成し、一つのプログラムにまとめなさい．
# **〆切：10/29（日）までにGoogleClassroomでjupyter notebook形式「id_学籍番号_04.ipynb」形式で送ること**

# %% [markdown]
# ## 15.3 scipy.optimizeパッケージを用いた非線形方程式の解法

# %% [markdown]
# Pythonに用意されている`scipy`という科学技術計算ライブラリが用意されており，その中に最適化パッケージ`optimize`があります．その中に2分法とニュートン法もあります．
#
# $x^2-1=0$
#
# をライブラリに用意されているニュートン法の関数`scipy.optimize.newton()`を用いて解いてみます．

# %%
# !poetry add scipy
# Out:
# Using version ^1.14.1 for scipy
#
# Updating dependencies
# Resolving dependencies... (0.2s)
#
# Package operations: 44 installs, 11 updates, 0 removals
#
#   - Downgrading jsonschema-specifications (2024.10.1 -> 2023.12.1): Pending...
#   - Downgrading types-python-dateutil (2.9.0.20241003 -> 2.9.0.20240906): Pending...
#   - Downgrading types-python-dateutil (2.9.0.20241003 -> 2.9.0.20240906): Installing...
#   - Downgrading types-python-dateutil (2.9.0.20241003 -> 2.9.0.20240906): Installing...
#   - Downgrading jsonschema-specifications (2024.10.1 -> 2023.12.1): Installing...
#   - Downgrading types-python-dateutil (2.9.0.20241003 -> 2.9.0.20240906): Installing...
#   - Downgrading types-python-dateutil (2.9.0.20241003 -> 2.9.0.20240906)
#   - Downgrading types-python-dateutil (2.9.0.20241003 -> 2.9.0.20240906)
#   - Downgrading jsonschema-specifications (2024.10.1 -> 2023.12.1)
#   - Downgrading types-python-dateutil (2.9.0.20241003 -> 2.9.0.20240906)
#   - Downgrading markupsafe (3.0.1 -> 2.1.5): Pending...
#   - Downgrading markupsafe (3.0.1 -> 2.1.5): Installing...
#   - Downgrading markupsafe (3.0.1 -> 2.1.5)
#   - Downgrading anyio (4.6.2.post1 -> 4.6.0): Pending...
#   - Installing mdurl (0.1.2): Pending...
#   - Downgrading prompt-toolkit (3.0.48 -> 3.0.47): Pending...
#   - Downgrading charset-normalizer (3.4.0 -> 3.3.2): Pending...
#   - Downgrading charset-normalizer (3.4.0 -> 3.3.2): Installing...
#   - Downgrading prompt-toolkit (3.0.48 -> 3.0.47): Pending...
#   - Downgrading charset-normalizer (3.4.0 -> 3.3.2): Installing...
#   - Installing mdurl (0.1.2): Installing...
#   - Downgrading prompt-toolkit (3.0.48 -> 3.0.47): Pending...
#   - Downgrading charset-normalizer (3.4.0 -> 3.3.2): Installing...
#   - Downgrading prompt-toolkit (3.0.48 -> 3.0.47): Pending...
#   - Downgrading charset-normalizer (3.4.0 -> 3.3.2): Installing...
#   - Installing mdurl (0.1.2)
#   - Downgrading prompt-toolkit (3.0.48 -> 3.0.47): Pending...
#   - Downgrading charset-normalizer (3.4.0 -> 3.3.2): Installing...
#   - Downgrading charset-normalizer (3.4.0 -> 3.3.2): Installing...
#   - Downgrading prompt-toolkit (3.0.48 -> 3.0.47): Installing...
#   - Downgrading charset-normalizer (3.4.0 -> 3.3.2): Installing...
#   - Installing mdurl (0.1.2)
#   - Downgrading prompt-toolkit (3.0.48 -> 3.0.47): Installing...
#   - Downgrading charset-normalizer (3.4.0 -> 3.3.2): Installing...
#   - Downgrading anyio (4.6.2.post1 -> 4.6.0): Installing...
#   - Installing mdurl (0.1.2)
#   - Downgrading prompt-toolkit (3.0.48 -> 3.0.47): Installing...
#   - Downgrading charset-normalizer (3.4.0 -> 3.3.2): Installing...
#   - Downgrading charset-normalizer (3.4.0 -> 3.3.2)
#   - Downgrading charset-normalizer (3.4.0 -> 3.3.2)
#   - Downgrading prompt-toolkit (3.0.48 -> 3.0.47)
#   - Downgrading charset-normalizer (3.4.0 -> 3.3.2)
#   - Installing mdurl (0.1.2)
#   - Downgrading prompt-toolkit (3.0.48 -> 3.0.47)
#   - Downgrading charset-normalizer (3.4.0 -> 3.3.2)
#   - Downgrading anyio (4.6.2.post1 -> 4.6.0)
#   - Installing mdurl (0.1.2)
#   - Downgrading prompt-toolkit (3.0.48 -> 3.0.47)
#   - Downgrading charset-normalizer (3.4.0 -> 3.3.2)
#   - Installing alabaster (0.7.16): Pending...
#   - Downgrading debugpy (1.8.7 -> 1.8.5): Pending...
#   - Installing docutils (0.20.1): Pending...
#   - Downgrading httpcore (1.0.6 -> 1.0.5): Pending...
#   - Installing imagesize (1.4.1): Pending...
#   - Downgrading ipython (8.28.0 -> 8.27.0): Pending...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing snowballstemmer (2.2.0): Pending...
#   - Installing sphinxcontrib-applehelp (2.0.0): Pending...
#   - Installing sphinxcontrib-devhelp (2.0.0): Pending...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Downgrading debugpy (1.8.7 -> 1.8.5): Pending...
#   - Installing docutils (0.20.1): Pending...
#   - Downgrading httpcore (1.0.6 -> 1.0.5): Pending...
#   - Installing imagesize (1.4.1): Pending...
#   - Downgrading ipython (8.28.0 -> 8.27.0): Pending...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing snowballstemmer (2.2.0): Pending...
#   - Installing sphinxcontrib-applehelp (2.0.0): Pending...
#   - Installing sphinxcontrib-devhelp (2.0.0): Pending...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Installing alabaster (0.7.16): Installing...
#   - Downgrading debugpy (1.8.7 -> 1.8.5): Pending...
#   - Installing docutils (0.20.1): Pending...
#   - Downgrading httpcore (1.0.6 -> 1.0.5): Pending...
#   - Installing imagesize (1.4.1): Pending...
#   - Downgrading ipython (8.28.0 -> 8.27.0): Pending...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing snowballstemmer (2.2.0): Pending...
#   - Installing sphinxcontrib-applehelp (2.0.0): Pending...
#   - Installing sphinxcontrib-devhelp (2.0.0): Pending...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Downgrading httpcore (1.0.6 -> 1.0.5): Pending...
#   - Installing imagesize (1.4.1): Pending...
#   - Downgrading ipython (8.28.0 -> 8.27.0): Pending...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing snowballstemmer (2.2.0): Pending...
#   - Installing sphinxcontrib-applehelp (2.0.0): Pending...
#   - Installing sphinxcontrib-devhelp (2.0.0): Pending...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Installing docutils (0.20.1): Installing...
#   - Downgrading httpcore (1.0.6 -> 1.0.5): Pending...
#   - Installing imagesize (1.4.1): Pending...
#   - Downgrading ipython (8.28.0 -> 8.27.0): Pending...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing snowballstemmer (2.2.0): Pending...
#   - Installing sphinxcontrib-applehelp (2.0.0): Pending...
#   - Installing sphinxcontrib-devhelp (2.0.0): Pending...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Installing imagesize (1.4.1): Pending...
#   - Downgrading ipython (8.28.0 -> 8.27.0): Pending...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing snowballstemmer (2.2.0): Pending...
#   - Installing sphinxcontrib-applehelp (2.0.0): Pending...
#   - Installing sphinxcontrib-devhelp (2.0.0): Pending...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Downgrading httpcore (1.0.6 -> 1.0.5): Installing...
#   - Installing imagesize (1.4.1): Pending...
#   - Downgrading ipython (8.28.0 -> 8.27.0): Pending...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing snowballstemmer (2.2.0): Pending...
#   - Installing sphinxcontrib-applehelp (2.0.0): Pending...
#   - Installing sphinxcontrib-devhelp (2.0.0): Pending...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Downgrading debugpy (1.8.7 -> 1.8.5): Pending...
#   - Installing docutils (0.20.1): Installing...
#   - Downgrading httpcore (1.0.6 -> 1.0.5): Installing...
#   - Installing imagesize (1.4.1): Pending...
#   - Downgrading ipython (8.28.0 -> 8.27.0): Pending...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing snowballstemmer (2.2.0): Pending...
#   - Installing sphinxcontrib-applehelp (2.0.0): Pending...
#   - Installing sphinxcontrib-devhelp (2.0.0): Pending...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Installing alabaster (0.7.16)
#   - Downgrading debugpy (1.8.7 -> 1.8.5): Pending...
#   - Installing docutils (0.20.1): Installing...
#   - Downgrading httpcore (1.0.6 -> 1.0.5): Installing...
#   - Installing imagesize (1.4.1): Pending...
#   - Downgrading ipython (8.28.0 -> 8.27.0): Pending...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing snowballstemmer (2.2.0): Pending...
#   - Installing sphinxcontrib-applehelp (2.0.0): Pending...
#   - Installing sphinxcontrib-devhelp (2.0.0): Pending...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Installing sphinxcontrib-jsmath (1.0.1): Pending...
#   - Installing docutils (0.20.1): Installing...
#   - Downgrading httpcore (1.0.6 -> 1.0.5): Installing...
#   - Installing imagesize (1.4.1): Pending...
#   - Downgrading ipython (8.28.0 -> 8.27.0): Pending...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing snowballstemmer (2.2.0): Pending...
#   - Installing sphinxcontrib-applehelp (2.0.0): Pending...
#   - Installing sphinxcontrib-devhelp (2.0.0): Pending...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Installing sphinxcontrib-jsmath (1.0.1): Pending...
#   - Downgrading debugpy (1.8.7 -> 1.8.5): Installing...
#   - Installing docutils (0.20.1): Installing...
#   - Downgrading httpcore (1.0.6 -> 1.0.5): Installing...
#   - Installing imagesize (1.4.1): Pending...
#   - Downgrading ipython (8.28.0 -> 8.27.0): Pending...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing snowballstemmer (2.2.0): Pending...
#   - Installing sphinxcontrib-applehelp (2.0.0): Pending...
#   - Installing sphinxcontrib-devhelp (2.0.0): Pending...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Installing sphinxcontrib-jsmath (1.0.1): Pending...
#   - Downgrading ipython (8.28.0 -> 8.27.0): Pending...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing snowballstemmer (2.2.0): Pending...
#   - Installing sphinxcontrib-applehelp (2.0.0): Pending...
#   - Installing sphinxcontrib-devhelp (2.0.0): Pending...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Installing sphinxcontrib-jsmath (1.0.1): Pending...
#   - Installing imagesize (1.4.1): Installing...
#   - Downgrading ipython (8.28.0 -> 8.27.0): Pending...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Pending...
#   - Installing snowballstemmer (2.2.0): Pending...
#   - Installing sphinxcontrib-applehelp (2.0.0): Pending...
#   - Installing sphinxcontrib-devhelp (2.0.0): Pending...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Installing sphinxcontrib-jsmath (1.0.1): Pending...
#   - Installing sphinxcontrib-jsmath (1.0.1): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Installing sphinxcontrib-jsmath (1.0.1): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Installing sphinxcontrib-jsmath (1.0.1): Installing...
#   - Installing sphinxcontrib-applehelp (2.0.0): Pending...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Installing sphinxcontrib-jsmath (1.0.1): Installing...
#   - Installing snowballstemmer (2.2.0): Installing...
#   - Installing sphinxcontrib-applehelp (2.0.0): Pending...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Pending...
#   - Installing sphinxcontrib-jsmath (1.0.1): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1): Installing...
#   - Installing sphinxcontrib-applehelp (2.0.0): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1): Installing...
#   - Installing snowballstemmer (2.2.0): Installing...
#   - Installing sphinxcontrib-applehelp (2.0.0): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1): Installing...
#   - Installing markdown-it-py (3.0.0): Installing...
#   - Installing snowballstemmer (2.2.0): Installing...
#   - Installing sphinxcontrib-applehelp (2.0.0): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1): Installing...
#   - Downgrading ipython (8.28.0 -> 8.27.0): Pending...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Installing...
#   - Installing snowballstemmer (2.2.0): Installing...
#   - Installing sphinxcontrib-applehelp (2.0.0): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1): Installing...
#   - Installing imagesize (1.4.1)
#   - Downgrading ipython (8.28.0 -> 8.27.0): Pending...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Installing...
#   - Installing snowballstemmer (2.2.0): Installing...
#   - Installing sphinxcontrib-applehelp (2.0.0): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1): Installing...
#   - Installing sphinxcontrib-qthelp (2.0.0): Pending...
#   - Installing sphinxcontrib-qthelp (2.0.0): Pending...
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Pending...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Pending...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Installing...
#   - Installing snowballstemmer (2.2.0): Installing...
#   - Installing sphinxcontrib-applehelp (2.0.0): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Pending...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Pending...
#   - Downgrading ipython (8.28.0 -> 8.27.0): Installing...
#   - Installing latexcodec (3.0.0): Pending...
#   - Installing markdown-it-py (3.0.0): Installing...
#   - Installing snowballstemmer (2.2.0): Installing...
#   - Installing sphinxcontrib-applehelp (2.0.0): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Pending...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Pending...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Pending...
#   - Installing sphinxcontrib-qthelp (2.0.0): Installing...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Pending...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing sphinxcontrib-applehelp (2.0.0): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Installing...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing snowballstemmer (2.2.0)
#   - Installing sphinxcontrib-applehelp (2.0.0): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Installing...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2): Pending...
#   - Installing typing-extensions (4.12.2): Installing...
#   - Installing markdown-it-py (3.0.0): Installing...
#   - Installing snowballstemmer (2.2.0)
#   - Installing sphinxcontrib-applehelp (2.0.0): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Installing...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2): Installing...
#   - Installing latexcodec (3.0.0): Installing...
#   - Installing markdown-it-py (3.0.0): Installing...
#   - Installing snowballstemmer (2.2.0)
#   - Installing sphinxcontrib-applehelp (2.0.0): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Installing...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2): Installing...
#   - Installing snowballstemmer (2.2.0)
#   - Installing sphinxcontrib-applehelp (2.0.0): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Installing...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2): Installing...
#   - Installing markdown-it-py (3.0.0)
#   - Installing snowballstemmer (2.2.0)
#   - Installing sphinxcontrib-applehelp (2.0.0): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Installing...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2): Installing...
#   - Installing zipp (3.20.2): Pending...
#   - Installing zipp (3.20.2): Pending...
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2): Pending...
#   - Installing markdown-it-py (3.0.0)
#   - Installing snowballstemmer (2.2.0)
#   - Installing sphinxcontrib-applehelp (2.0.0): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Installing...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2): Pending...
#   - Installing latexcodec (3.0.0)
#   - Installing markdown-it-py (3.0.0)
#   - Installing snowballstemmer (2.2.0)
#   - Installing sphinxcontrib-applehelp (2.0.0): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Installing...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2): Pending...
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Installing...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2): Pending...
#   - Installing sphinxcontrib-devhelp (2.0.0)
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Installing...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2): Pending...
#   - Installing zipp (3.20.2): Installing...
#   - Installing sphinxcontrib-devhelp (2.0.0)
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Installing...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2): Installing...
#   - Installing sphinxcontrib-applehelp (2.0.0)
#   - Installing sphinxcontrib-devhelp (2.0.0)
#   - Installing sphinxcontrib-htmlhelp (2.1.0): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Installing...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2): Installing...
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Installing...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2): Installing...
#   - Installing sphinxcontrib-htmlhelp (2.1.0)
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0): Installing...
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2): Installing...
#   - Installing zipp (3.20.2)
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2)
#   - Installing sphinxcontrib-qthelp (2.0.0)
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2)
#   - Downgrading httpcore (1.0.6 -> 1.0.5): Installing...
#   - Installing imagesize (1.4.1)
#   - Downgrading ipython (8.28.0 -> 8.27.0): Installing...
#   - Installing latexcodec (3.0.0)
#   - Installing markdown-it-py (3.0.0)
#   - Installing snowballstemmer (2.2.0)
#   - Installing sphinxcontrib-applehelp (2.0.0)
#   - Installing sphinxcontrib-devhelp (2.0.0)
#   - Installing sphinxcontrib-htmlhelp (2.1.0)
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0)
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2)
#   - Installing docutils (0.20.1)
#   - Downgrading httpcore (1.0.6 -> 1.0.5): Installing...
#   - Installing imagesize (1.4.1)
#   - Downgrading ipython (8.28.0 -> 8.27.0): Installing...
#   - Installing latexcodec (3.0.0)
#   - Installing markdown-it-py (3.0.0)
#   - Installing snowballstemmer (2.2.0)
#   - Installing sphinxcontrib-applehelp (2.0.0)
#   - Installing sphinxcontrib-devhelp (2.0.0)
#   - Installing sphinxcontrib-htmlhelp (2.1.0)
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0)
#   - Installing sphinxcontrib-serializinghtml (2.0.0): Installing...
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2)
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2)
#   - Installing sphinxcontrib-serializinghtml (2.0.0)
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2)
#   - Installing imagesize (1.4.1)
#   - Downgrading ipython (8.28.0 -> 8.27.0): Installing...
#   - Installing latexcodec (3.0.0)
#   - Installing markdown-it-py (3.0.0)
#   - Installing snowballstemmer (2.2.0)
#   - Installing sphinxcontrib-applehelp (2.0.0)
#   - Installing sphinxcontrib-devhelp (2.0.0)
#   - Installing sphinxcontrib-htmlhelp (2.1.0)
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0)
#   - Installing sphinxcontrib-serializinghtml (2.0.0)
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2)
#   - Downgrading httpcore (1.0.6 -> 1.0.5)
#   - Installing imagesize (1.4.1)
#   - Downgrading ipython (8.28.0 -> 8.27.0): Installing...
#   - Installing latexcodec (3.0.0)
#   - Installing markdown-it-py (3.0.0)
#   - Installing snowballstemmer (2.2.0)
#   - Installing sphinxcontrib-applehelp (2.0.0)
#   - Installing sphinxcontrib-devhelp (2.0.0)
#   - Installing sphinxcontrib-htmlhelp (2.1.0)
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0)
#   - Installing sphinxcontrib-serializinghtml (2.0.0)
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2)
#   - Installing docutils (0.20.1)
#   - Downgrading httpcore (1.0.6 -> 1.0.5)
#   - Installing imagesize (1.4.1)
#   - Downgrading ipython (8.28.0 -> 8.27.0): Installing...
#   - Installing latexcodec (3.0.0)
#   - Installing markdown-it-py (3.0.0)
#   - Installing snowballstemmer (2.2.0)
#   - Installing sphinxcontrib-applehelp (2.0.0)
#   - Installing sphinxcontrib-devhelp (2.0.0)
#   - Installing sphinxcontrib-htmlhelp (2.1.0)
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0)
#   - Installing sphinxcontrib-serializinghtml (2.0.0)
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2)
#   - Downgrading debugpy (1.8.7 -> 1.8.5)
#   - Installing docutils (0.20.1)
#   - Downgrading httpcore (1.0.6 -> 1.0.5)
#   - Installing imagesize (1.4.1)
#   - Downgrading ipython (8.28.0 -> 8.27.0): Installing...
#   - Installing latexcodec (3.0.0)
#   - Installing markdown-it-py (3.0.0)
#   - Installing snowballstemmer (2.2.0)
#   - Installing sphinxcontrib-applehelp (2.0.0)
#   - Installing sphinxcontrib-devhelp (2.0.0)
#   - Installing sphinxcontrib-htmlhelp (2.1.0)
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0)
#   - Installing sphinxcontrib-serializinghtml (2.0.0)
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2)
#   - Installing latexcodec (3.0.0)
#   - Installing markdown-it-py (3.0.0)
#   - Installing snowballstemmer (2.2.0)
#   - Installing sphinxcontrib-applehelp (2.0.0)
#   - Installing sphinxcontrib-devhelp (2.0.0)
#   - Installing sphinxcontrib-htmlhelp (2.1.0)
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0)
#   - Installing sphinxcontrib-serializinghtml (2.0.0)
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2)
#   - Downgrading ipython (8.28.0 -> 8.27.0)
#   - Installing latexcodec (3.0.0)
#   - Installing markdown-it-py (3.0.0)
#   - Installing snowballstemmer (2.2.0)
#   - Installing sphinxcontrib-applehelp (2.0.0)
#   - Installing sphinxcontrib-devhelp (2.0.0)
#   - Installing sphinxcontrib-htmlhelp (2.1.0)
#   - Installing sphinxcontrib-jsmath (1.0.1)
#   - Installing sphinxcontrib-qthelp (2.0.0)
#   - Installing sphinxcontrib-serializinghtml (2.0.0)
#   - Installing typing-extensions (4.12.2)
#   - Installing zipp (3.20.2)
#   - Installing accessible-pygments (0.0.5): Pending...
#   - Installing pybtex (0.24.0): Pending...
#   - Downgrading setuptools (75.2.0 -> 75.1.0): Pending...
#   - Installing sphinx (7.4.7): Pending...
#   - Installing sqlalchemy (2.0.35): Pending...
#   - Installing tabulate (0.9.0): Pending...
#   - Installing click (8.1.7): Pending...
#   - Installing importlib-metadata (8.5.0): Pending...
#   - Installing mdit-py-plugins (0.4.2): Pending...
#   - Installing click (8.1.7): Pending...
#   - Installing importlib-metadata (8.5.0): Pending...
#   - Installing mdit-py-plugins (0.4.2): Pending...
#   - Installing tabulate (0.9.0): Installing...
#   - Installing click (8.1.7): Pending...
#   - Installing importlib-metadata (8.5.0): Pending...
#   - Installing mdit-py-plugins (0.4.2): Pending...
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Installing importlib-metadata (8.5.0): Installing...
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Installing importlib-metadata (8.5.0): Installing...
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Installing click (8.1.7): Installing...
#   - Installing importlib-metadata (8.5.0): Installing...
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Installing click (8.1.7): Installing...
#   - Installing importlib-metadata (8.5.0): Installing...
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7): Installing...
#   - Installing importlib-metadata (8.5.0): Installing...
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Installing sphinx (7.4.7): Pending...
#   - Installing sqlalchemy (2.0.35): Pending...
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7): Installing...
#   - Installing importlib-metadata (8.5.0): Installing...
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Downgrading setuptools (75.2.0 -> 75.1.0): Installing...
#   - Installing sphinx (7.4.7): Pending...
#   - Installing sqlalchemy (2.0.35): Pending...
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7): Installing...
#   - Installing importlib-metadata (8.5.0): Installing...
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7): Installing...
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Installing sqlalchemy (2.0.35): Installing...
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7): Installing...
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Installing sqlalchemy (2.0.35): Installing...
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Installing sphinx (7.4.7): Installing...
#   - Installing sqlalchemy (2.0.35): Installing...
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2): Installing...
#   - Installing mdit-py-plugins (0.4.2)
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2)
#   - Installing sqlalchemy (2.0.35)
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2)
#   - Downgrading setuptools (75.2.0 -> 75.1.0): Installing...
#   - Installing sphinx (7.4.7): Installing...
#   - Installing sqlalchemy (2.0.35)
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2)
#   - Installing pybtex (0.24.0): Installing...
#   - Downgrading setuptools (75.2.0 -> 75.1.0): Installing...
#   - Installing sphinx (7.4.7): Installing...
#   - Installing sqlalchemy (2.0.35)
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2)
#   - Installing pybtex (0.24.0): Installing...
#   - Downgrading setuptools (75.2.0 -> 75.1.0): Installing...
#   - Installing sphinx (7.4.7): Installing...
#   - Installing sqlalchemy (2.0.35)
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2)
#   - Installing accessible-pygments (0.0.5): Installing...
#   - Installing pybtex (0.24.0): Installing...
#   - Downgrading setuptools (75.2.0 -> 75.1.0): Installing...
#   - Installing sphinx (7.4.7): Installing...
#   - Installing sqlalchemy (2.0.35)
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2)
#   - Installing pybtex (0.24.0): Installing...
#   - Downgrading setuptools (75.2.0 -> 75.1.0): Installing...
#   - Installing sphinx (7.4.7): Installing...
#   - Installing sqlalchemy (2.0.35)
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2)
#   - Installing accessible-pygments (0.0.5)
#   - Installing pybtex (0.24.0): Installing...
#   - Downgrading setuptools (75.2.0 -> 75.1.0): Installing...
#   - Installing sphinx (7.4.7): Installing...
#   - Installing sqlalchemy (2.0.35)
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2)
#   - Downgrading setuptools (75.2.0 -> 75.1.0): Installing...
#   - Installing sphinx (7.4.7): Installing...
#   - Installing sqlalchemy (2.0.35)
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2)
#   - Installing pybtex (0.24.0)
#   - Downgrading setuptools (75.2.0 -> 75.1.0): Installing...
#   - Installing sphinx (7.4.7): Installing...
#   - Installing sqlalchemy (2.0.35)
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2)
#   - Installing sqlalchemy (2.0.35)
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2)
#   - Installing sphinx (7.4.7)
#   - Installing sqlalchemy (2.0.35)
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2)
#   - Installing sphinx (7.4.7)
#   - Installing sqlalchemy (2.0.35)
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2)
#   - Downgrading setuptools (75.2.0 -> 75.1.0)
#   - Installing sphinx (7.4.7)
#   - Installing sqlalchemy (2.0.35)
#   - Installing tabulate (0.9.0)
#   - Installing click (8.1.7)
#   - Installing importlib-metadata (8.5.0)
#   - Installing mdit-py-plugins (0.4.2)
#   - Installing jupyter-cache (1.0.0): Pending...
#   - Installing myst-parser (2.0.0): Pending...
#   - Installing pybtex-docutils (1.0.3): Pending...
#   - Installing pydata-sphinx-theme (0.15.4): Pending...
#   - Installing uc-micro-py (1.0.3): Pending...
#   - Installing wheel (0.44.0): Pending...
#   - Installing wheel (0.44.0): Installing...
#   - Installing wheel (0.44.0)
#   - Installing myst-parser (2.0.0): Pending...
#   - Installing pybtex-docutils (1.0.3): Pending...
#   - Installing pydata-sphinx-theme (0.15.4): Pending...
#   - Installing uc-micro-py (1.0.3): Pending...
#   - Installing wheel (0.44.0)
#   - Installing jupyter-cache (1.0.0): Installing...
#   - Installing myst-parser (2.0.0): Pending...
#   - Installing pybtex-docutils (1.0.3): Pending...
#   - Installing pydata-sphinx-theme (0.15.4): Pending...
#   - Installing uc-micro-py (1.0.3): Pending...
#   - Installing wheel (0.44.0)
#   - Installing pydata-sphinx-theme (0.15.4): Pending...
#   - Installing uc-micro-py (1.0.3): Pending...
#   - Installing wheel (0.44.0)
#   - Installing pybtex-docutils (1.0.3): Installing...
#   - Installing pydata-sphinx-theme (0.15.4): Pending...
#   - Installing uc-micro-py (1.0.3): Pending...
#   - Installing wheel (0.44.0)
#   - Installing wheel (0.44.0)
#   - Installing uc-micro-py (1.0.3): Installing...
#   - Installing wheel (0.44.0)
#   - Installing pybtex-docutils (1.0.3): Installing...
#   - Installing pydata-sphinx-theme (0.15.4): Pending...
#   - Installing uc-micro-py (1.0.3): Installing...
#   - Installing wheel (0.44.0)
#   - Installing myst-parser (2.0.0): Installing...
#   - Installing pybtex-docutils (1.0.3): Installing...
#   - Installing pydata-sphinx-theme (0.15.4): Pending...
#   - Installing uc-micro-py (1.0.3): Installing...
#   - Installing wheel (0.44.0)
#   - Installing pydata-sphinx-theme (0.15.4): Pending...
#   - Installing uc-micro-py (1.0.3): Installing...
#   - Installing wheel (0.44.0)
#   - Installing pybtex-docutils (1.0.3)
#   - Installing pydata-sphinx-theme (0.15.4): Pending...
#   - Installing uc-micro-py (1.0.3): Installing...
#   - Installing wheel (0.44.0)
#   - Installing wheel (0.44.0)
#   - Installing uc-micro-py (1.0.3)
#   - Installing wheel (0.44.0)
#   - Installing myst-parser (2.0.0): Installing...
#   - Installing pybtex-docutils (1.0.3)
#   - Installing pydata-sphinx-theme (0.15.4): Pending...
#   - Installing uc-micro-py (1.0.3)
#   - Installing wheel (0.44.0)
#   - Installing jupyter-cache (1.0.0)
#   - Installing myst-parser (2.0.0): Installing...
#   - Installing pybtex-docutils (1.0.3)
#   - Installing pydata-sphinx-theme (0.15.4): Pending...
#   - Installing uc-micro-py (1.0.3)
#   - Installing wheel (0.44.0)
#   - Installing uc-micro-py (1.0.3)
#   - Installing wheel (0.44.0)
#   - Installing pydata-sphinx-theme (0.15.4): Installing...
#   - Installing uc-micro-py (1.0.3)
#   - Installing wheel (0.44.0)
#   - Installing pybtex-docutils (1.0.3)
#   - Installing pydata-sphinx-theme (0.15.4): Installing...
#   - Installing uc-micro-py (1.0.3)
#   - Installing wheel (0.44.0)
#   - Installing myst-parser (2.0.0)
#   - Installing pybtex-docutils (1.0.3)
#   - Installing pydata-sphinx-theme (0.15.4): Installing...
#   - Installing uc-micro-py (1.0.3)
#   - Installing wheel (0.44.0)
#   - Installing uc-micro-py (1.0.3)
#   - Installing wheel (0.44.0)
#   - Installing pydata-sphinx-theme (0.15.4)
#   - Installing uc-micro-py (1.0.3)
#   - Installing wheel (0.44.0)
#   - Installing linkify-it-py (2.0.3): Pending...
#   - Installing myst-nb (1.1.1): Pending...
#   - Updating numpy (1.26.4 -> 2.1.1): Pending...
#   - Installing sphinx-book-theme (1.1.3): Pending...
#   - Installing sphinx-comments (0.0.3): Pending...
#   - Installing sphinx-copybutton (0.5.2): Pending...
#   - Installing sphinx-design (0.6.1): Pending...
#   - Installing sphinx-external-toc (1.0.1): Pending...
#   - Installing sphinx-jupyterbook-latex (1.0.0): Pending...
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Pending...
#   - Installing sphinx-book-theme (1.1.3): Pending...
#   - Installing sphinx-comments (0.0.3): Pending...
#   - Installing sphinx-copybutton (0.5.2): Pending...
#   - Installing sphinx-design (0.6.1): Pending...
#   - Installing sphinx-external-toc (1.0.1): Pending...
#   - Installing sphinx-jupyterbook-latex (1.0.0): Pending...
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Pending...
#   - Updating numpy (1.26.4 -> 2.1.1): Installing...
#   - Installing sphinx-book-theme (1.1.3): Pending...
#   - Installing sphinx-comments (0.0.3): Pending...
#   - Installing sphinx-copybutton (0.5.2): Pending...
#   - Installing sphinx-design (0.6.1): Pending...
#   - Installing sphinx-external-toc (1.0.1): Pending...
#   - Installing sphinx-jupyterbook-latex (1.0.0): Pending...
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Pending...
#   - Installing sphinx-jupyterbook-latex (1.0.0): Pending...
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Pending...
#   - Installing sphinx-external-toc (1.0.1): Installing...
#   - Installing sphinx-jupyterbook-latex (1.0.0): Pending...
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Pending...
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Pending...
#   - Installing sphinx-jupyterbook-latex (1.0.0): Installing...
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Pending...
#   - Installing sphinx-comments (0.0.3): Pending...
#   - Installing sphinx-copybutton (0.5.2): Pending...
#   - Installing sphinx-design (0.6.1): Pending...
#   - Installing sphinx-external-toc (1.0.1): Installing...
#   - Installing sphinx-jupyterbook-latex (1.0.0): Installing...
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Pending...
#   - Installing sphinx-book-theme (1.1.3): Installing...
#   - Installing sphinx-comments (0.0.3): Pending...
#   - Installing sphinx-copybutton (0.5.2): Pending...
#   - Installing sphinx-design (0.6.1): Pending...
#   - Installing sphinx-external-toc (1.0.1): Installing...
#   - Installing sphinx-jupyterbook-latex (1.0.0): Installing...
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Pending...
#   - Installing sphinx-design (0.6.1): Pending...
#   - Installing sphinx-external-toc (1.0.1): Installing...
#   - Installing sphinx-jupyterbook-latex (1.0.0): Installing...
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Pending...
#   - Installing sphinx-copybutton (0.5.2): Installing...
#   - Installing sphinx-design (0.6.1): Pending...
#   - Installing sphinx-external-toc (1.0.1): Installing...
#   - Installing sphinx-jupyterbook-latex (1.0.0): Installing...
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Pending...
#   - Installing sphinx-copybutton (0.5.2): Installing...
#   - Installing sphinx-design (0.6.1): Pending...
#   - Installing sphinx-external-toc (1.0.1): Installing...
#   - Installing sphinx-jupyterbook-latex (1.0.0): Installing...
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Pending...
#   - Installing sphinx-comments (0.0.3): Installing...
#   - Installing sphinx-copybutton (0.5.2): Installing...
#   - Installing sphinx-design (0.6.1): Pending...
#   - Installing sphinx-external-toc (1.0.1): Installing...
#   - Installing sphinx-jupyterbook-latex (1.0.0): Installing...
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Installing...
#   - Updating numpy (1.26.4 -> 2.1.1): Installing...
#   - Installing sphinx-book-theme (1.1.3): Installing...
#   - Installing sphinx-comments (0.0.3): Installing...
#   - Installing sphinx-copybutton (0.5.2): Installing...
#   - Installing sphinx-design (0.6.1): Pending...
#   - Installing sphinx-external-toc (1.0.1): Installing...
#   - Installing sphinx-jupyterbook-latex (1.0.0): Installing...
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Installing...
#   - Installing myst-nb (1.1.1): Installing...
#   - Updating numpy (1.26.4 -> 2.1.1): Installing...
#   - Installing sphinx-book-theme (1.1.3): Installing...
#   - Installing sphinx-comments (0.0.3): Installing...
#   - Installing sphinx-copybutton (0.5.2): Installing...
#   - Installing sphinx-design (0.6.1): Pending...
#   - Installing sphinx-external-toc (1.0.1): Installing...
#   - Installing sphinx-jupyterbook-latex (1.0.0): Installing...
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Installing...
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Installing...
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Installing...
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-copybutton (0.5.2): Installing...
#   - Installing sphinx-design (0.6.1): Pending...
#   - Installing sphinx-external-toc (1.0.1): Installing...
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Installing...
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-comments (0.0.3)
#   - Installing sphinx-copybutton (0.5.2): Installing...
#   - Installing sphinx-design (0.6.1): Pending...
#   - Installing sphinx-external-toc (1.0.1): Installing...
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Installing...
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Installing...
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Installing...
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-design (0.6.1): Pending...
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Installing...
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-copybutton (0.5.2)
#   - Installing sphinx-design (0.6.1): Pending...
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2): Installing...
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-design (0.6.1): Installing...
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Updating numpy (1.26.4 -> 2.1.1): Installing...
#   - Installing sphinx-book-theme (1.1.3): Installing...
#   - Installing sphinx-comments (0.0.3)
#   - Installing sphinx-copybutton (0.5.2)
#   - Installing sphinx-design (0.6.1): Installing...
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing myst-nb (1.1.1)
#   - Updating numpy (1.26.4 -> 2.1.1): Installing...
#   - Installing sphinx-book-theme (1.1.3): Installing...
#   - Installing sphinx-comments (0.0.3)
#   - Installing sphinx-copybutton (0.5.2)
#   - Installing sphinx-design (0.6.1): Installing...
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Pending...
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-thebe (0.3.1): Installing...
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-thebe (0.3.1)
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-thebe (0.3.1)
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-multitoc-numbering (0.1.3): Installing...
#   - Installing sphinx-thebe (0.3.1)
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-thebe (0.3.1)
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-multitoc-numbering (0.1.3)
#   - Installing sphinx-thebe (0.3.1)
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-comments (0.0.3)
#   - Installing sphinx-copybutton (0.5.2)
#   - Installing sphinx-design (0.6.1): Installing...
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3)
#   - Installing sphinx-thebe (0.3.1)
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-book-theme (1.1.3)
#   - Installing sphinx-comments (0.0.3)
#   - Installing sphinx-copybutton (0.5.2)
#   - Installing sphinx-design (0.6.1): Installing...
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3)
#   - Installing sphinx-thebe (0.3.1)
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3)
#   - Installing sphinx-thebe (0.3.1)
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinx-design (0.6.1)
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3)
#   - Installing sphinx-thebe (0.3.1)
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3): Pending...
#   - Installing sphinxcontrib-bibtex (2.6.3): Installing...
#   - Installing sphinxcontrib-bibtex (2.6.3)
#   - Installing myst-nb (1.1.1)
#   - Updating numpy (1.26.4 -> 2.1.1): Installing...
#   - Installing sphinx-book-theme (1.1.3)
#   - Installing sphinx-comments (0.0.3)
#   - Installing sphinx-copybutton (0.5.2)
#   - Installing sphinx-design (0.6.1)
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3)
#   - Installing sphinx-thebe (0.3.1)
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3)
#   - Installing linkify-it-py (2.0.3): Installing...
#   - Installing myst-nb (1.1.1)
#   - Updating numpy (1.26.4 -> 2.1.1): Installing...
#   - Installing sphinx-book-theme (1.1.3)
#   - Installing sphinx-comments (0.0.3)
#   - Installing sphinx-copybutton (0.5.2)
#   - Installing sphinx-design (0.6.1)
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3)
#   - Installing sphinx-thebe (0.3.1)
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3)
#   - Installing myst-nb (1.1.1)
#   - Updating numpy (1.26.4 -> 2.1.1): Installing...
#   - Installing sphinx-book-theme (1.1.3)
#   - Installing sphinx-comments (0.0.3)
#   - Installing sphinx-copybutton (0.5.2)
#   - Installing sphinx-design (0.6.1)
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3)
#   - Installing sphinx-thebe (0.3.1)
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3)
#   - Installing linkify-it-py (2.0.3)
#   - Installing myst-nb (1.1.1)
#   - Updating numpy (1.26.4 -> 2.1.1): Installing...
#   - Installing sphinx-book-theme (1.1.3)
#   - Installing sphinx-comments (0.0.3)
#   - Installing sphinx-copybutton (0.5.2)
#   - Installing sphinx-design (0.6.1)
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3)
#   - Installing sphinx-thebe (0.3.1)
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3)
#   - Installing sphinx-book-theme (1.1.3)
#   - Installing sphinx-comments (0.0.3)
#   - Installing sphinx-copybutton (0.5.2)
#   - Installing sphinx-design (0.6.1)
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3)
#   - Installing sphinx-thebe (0.3.1)
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3)
#   - Updating numpy (1.26.4 -> 2.1.1)
#   - Installing sphinx-book-theme (1.1.3)
#   - Installing sphinx-comments (0.0.3)
#   - Installing sphinx-copybutton (0.5.2)
#   - Installing sphinx-design (0.6.1)
#   - Installing sphinx-external-toc (1.0.1)
#   - Installing sphinx-jupyterbook-latex (1.0.0)
#   - Installing sphinx-multitoc-numbering (0.1.3)
#   - Installing sphinx-thebe (0.3.1)
#   - Installing sphinx-togglebutton (0.3.2)
#   - Installing sphinxcontrib-bibtex (2.6.3)
#   - Installing ghp-import (2.1.0): Pending...
#   - Installing jupyter-book (1.0.2): Pending...
#   - Installing scipy (1.14.1): Pending...
#   - Installing jupyter-book (1.0.2): Pending...
#   - Installing scipy (1.14.1): Pending...
#   - Installing ghp-import (2.1.0): Installing...
#   - Installing jupyter-book (1.0.2): Pending...
#   - Installing scipy (1.14.1): Pending...
#   - Installing jupyter-book (1.0.2): Pending...
#   - Installing scipy (1.14.1): Pending...
#   - Installing ghp-import (2.1.0)
#   - Installing jupyter-book (1.0.2): Pending...
#   - Installing scipy (1.14.1): Pending...
#   - Installing scipy (1.14.1): Downloading... 0%
#   - Installing scipy (1.14.1): Downloading... 0%
#   - Installing jupyter-book (1.0.2): Installing...
#   - Installing scipy (1.14.1): Downloading... 0%
#   - Installing scipy (1.14.1): Downloading... 0%
#   - Installing jupyter-book (1.0.2)
#   - Installing scipy (1.14.1): Downloading... 0%
#   - Installing scipy (1.14.1): Downloading... 10%
#   - Installing scipy (1.14.1): Downloading... 20%
#   - Installing scipy (1.14.1): Downloading... 27%
#   - Installing scipy (1.14.1): Downloading... 30%
#   - Installing scipy (1.14.1): Downloading... 37%
#   - Installing scipy (1.14.1): Downloading... 40%
#   - Installing scipy (1.14.1): Downloading... 48%
#   - Installing scipy (1.14.1): Downloading... 50%
#   - Installing scipy (1.14.1): Downloading... 54%
#   - Installing scipy (1.14.1): Downloading... 59%
#   - Installing scipy (1.14.1): Downloading... 66%
#   - Installing scipy (1.14.1): Downloading... 70%
#   - Installing scipy (1.14.1): Downloading... 74%
#   - Installing scipy (1.14.1): Downloading... 78%
#   - Installing scipy (1.14.1): Downloading... 80%
#   - Installing scipy (1.14.1): Downloading... 85%
#   - Installing scipy (1.14.1): Downloading... 90%
#   - Installing scipy (1.14.1): Downloading... 99%
#   - Installing scipy (1.14.1): Downloading... 100%
#   - Installing scipy (1.14.1): Installing...
#   - Installing scipy (1.14.1)
#
# Writing lock file

# %%
# scipy.optimize.newton()ニュートン法を用いる
import numpy as np
from scipy import optimize

def f(x): # 初めの式
    return x**2-1

print(optimize.newton(f, 0))
# Out:
# 1.0

# %% [markdown]
# 同じようにライブラリに用意されている2分法の関数`scipy.optimize.bisect()`を用いて
#
# $x^2-2=0$
#
# を解いてみます．

# %%
# scipy.optimize.newton()ニュートン法を用いる
import numpy as np
from scipy import optimize

def f(x): # 初めの式
    return x**2-2

print(optimize.bisect(f, 0, 2))
# Out:
# 1.4142135623715149
